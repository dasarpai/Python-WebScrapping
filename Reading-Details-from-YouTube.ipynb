# %%
url ="https://www.youtube.com/watch?time_continue=17&v=2wEA8nuThj8"
r = requests.get(url) 
s = BeautifulSoup(r.text, "html.parser")

# %%
#s.find("div",class="watch-main-col")
s.attrs()

# %%
# importing the libraries 
from bs4 import BeautifulSoup 
import requests 
global r
global s
  
# creating function 
def scrape_info(url): 
      
    # getting the request from url 
    r = requests.get(url) 
    print(r)
    # converting the text 
    s = BeautifulSoup(r.text, "html.parser") 
      
    # finding meta info for title 
    title = s.find("div", class_="watch-main-col") #.text.replace("\n", "") 
      
    # finding meta info for views 
    views = s.find("div", class_="watch-view-count").text 
      
    # finding meta info for likes 
    likes = s.find("span", class_="like-button-renderer").span.button.text 
      
    # saving this data in dictionary 
    data = {'title':title, 'views':views, 'likes':likes} 
      
    # returning the dictionary 
    return data 
  
# main function 
if __name__ == "__main__": 
      
    # URL of the video 
    url ="https://www.youtube.com/watch?time_continue=17&v=2wEA8nuThj8"
      
    # calling the function 
    data = scrape_info(url) 
      
    # printing the dictionary 
    print(data)
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-16931c14bd0a> in <module>
#      36
#      37     # calling the function
# ---> 38     data = scrape_info(url)
#      39
#      40     # printing the dictionary
#
# <ipython-input-43-16931c14bd0a> in scrape_info(url)
#      18
#      19     # finding meta info for views
# ---> 20     views = s.find("div", class_="watch-view-count").text
#      21
#      22     # finding meta info for likes
#
# AttributeError: 'NoneType' object has no attribute 'text'
